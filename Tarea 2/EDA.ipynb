# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('unemployment analysis.csv' , sep=",")

# %%
df.dtypes
# Out:
# Country Name     object
# Country Code     object
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %%
df.describe()
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean     7.278000    7.626340    8.070766    8.246043    8.333915    8.494894
# std      6.013749    6.296617    6.335855    6.243778    6.330822    6.358431
# min      0.300000    0.340000    0.410000    0.470000    0.500000    0.560000
# 25%      2.945000    3.140000    3.700000    3.890000    3.945000    3.995000
# 50%      5.410000    5.710000    6.030000    6.550000    6.700000    7.050000
# 75%      9.815000   10.170000   10.895000   11.110000   11.050000   11.405000
# max     36.120000   36.390000   36.740000   36.980000   37.340000   38.800000
#
#              1997        1998        1999        2000  ...        2012  \
# count  235.000000  235.000000  235.000000  235.000000  ...  235.000000
# mean     8.394043    8.441064    8.568043    8.438979  ...    8.062553
# ...

# %%
dfnew = pd.DataFrame()
for y in df.columns[ 2: ]:
    dftemp = df.loc[ : , ["Country Name","Country Code",y] ]
    dftemp["Year"] = y
    dftemp.columns = ['Country Name', 'Country Code', 'Value', 'Year']
    dftemp = dftemp.loc[ : , ['Country Name', 'Country Code', 'Year', 'Value'] ]
    
    dfnew = pd.concat([dfnew, dftemp])

# %%
df.columns[ 1 : 4 ]
# Out:
# Index(['Country Code', '1991', '1992'], dtype='object')

# %%
dfnew
# Out:
#                     Country Name Country Code  Year  Value
# 0    Africa Eastern and Southern          AFE  1991   7.80
# 1                    Afghanistan          AFG  1991  10.65
# 2     Africa Western and Central          AFW  1991   4.42
# 3                         Angola          AGO  1991   4.21
# 4                        Albania          ALB  1991  10.31
# ..                           ...          ...   ...    ...
# 230                        Samoa          WSM  2021   9.84
# 231                  Yemen, Rep.          YEM  2021  13.57
# 232                 South Africa          ZAF  2021  33.56
# 233                       Zambia          ZMB  2021  13.03
# 234                     Zimbabwe          ZWE  2021   5.17
#
# [7285 rows x 4 columns]

# %%
"""Version 1"""

dfCContinent = pd.read_csv('countryContinent.csv', sep=",",encoding = "ISO-8859-1")

# %%
dfCContinent
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
#           sub_region  region_code  sub_region_code
# ...

# %%
merged_left_country = pd.merge(dfnew,dfCContinent, left_on='Country Code', right_on='code_3', how='left').drop(
    columns=['code_2','sub_region','country_code','iso_3166_2','region_code','sub_region_code','code_3','country'])

# %%
merged_left_country
# Out:
#                      Country Name Country Code  Year  Value continent
# 0     Africa Eastern and Southern          AFE  1991   7.80       NaN
# 1                     Afghanistan          AFG  1991  10.65      Asia
# 2      Africa Western and Central          AFW  1991   4.42       NaN
# 3                          Angola          AGO  1991   4.21    Africa
# 4                         Albania          ALB  1991  10.31    Europe
# ...                           ...          ...   ...    ...       ...
# 7280                        Samoa          WSM  2021   9.84   Oceania
# 7281                  Yemen, Rep.          YEM  2021  13.57      Asia
# 7282                 South Africa          ZAF  2021  33.56    Africa
# 7283                       Zambia          ZMB  2021  13.03    Africa
# 7284                     Zimbabwe          ZWE  2021   5.17    Africa
#
# [7285 rows x 5 columns]

# %%
"""Version 2"""

dfPop=pd.read_csv('world_population.csv')

# %%
dfPop
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
merged_left_popC=pd.merge(dfnew,dfPop, left_on='Country Code', right_on='CCA3',how='left').drop(
    columns=['1980 Population','1970 Population','2022 Population','2020 Population','2015 Population',
             '2000 Population','2010 Population','1990 Population','Rank','Country','Capital','CCA3'])

# %%
"""Este me parecio mas completo para el ejercicio"""
merged_left_popC
# Out:
#                      Country Name Country Code  Year  Value Continent  \
# 0     Africa Eastern and Southern          AFE  1991   7.80       NaN
# 1                     Afghanistan          AFG  1991  10.65      Asia
# 2      Africa Western and Central          AFW  1991   4.42       NaN
# 3                          Angola          AGO  1991   4.21    Africa
# 4                         Albania          ALB  1991  10.31    Europe
# ...                           ...          ...   ...    ...       ...
# 7280                        Samoa          WSM  2021   9.84   Oceania
# 7281                  Yemen, Rep.          YEM  2021  13.57      Asia
# 7282                 South Africa          ZAF  2021  33.56    Africa
# 7283                       Zambia          ZMB  2021  13.03    Africa
# 7284                     Zimbabwe          ZWE  2021   5.17    Africa
#
#       Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# ...
